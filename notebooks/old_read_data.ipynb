# %%
import pandas as pd

# %%
#Reading the time series data of the index 'United Bank Of India EOD Prices'.
index = pd.read_csv("../data/raw/BSE-BOM533171.csv")
index.head(15)
# Out:
#           Date  Open  High   Low  Close   WAP  No. of Shares  No. of Trades  \
# 0   2020-03-20  4.50  4.70  4.45   4.48  4.54        36365.0          138.0
# 1   2020-03-19  4.55  4.67  4.15   4.50  4.43        65020.0          157.0
# 2   2020-03-18  4.74  4.75  4.39   4.43  4.52        70379.0          181.0
# 3   2020-03-17  4.65  4.86  4.61   4.64  4.70       101580.0          216.0
# 4   2020-03-16  4.81  4.88  4.55   4.66  4.70        95396.0          199.0
# 5   2020-03-13  4.59  5.00  4.13   4.76  4.39       246978.0          313.0
# 6   2020-03-12  5.14  5.14  4.50   4.58  4.67       134642.0          326.0
# 7   2020-03-11  6.20  6.20  5.30   5.33  5.43       183937.0          309.0
# 8   2020-03-09  5.70  5.71  5.16   5.38  5.36       188838.0          331.0
# 9   2020-03-06  5.99  6.37  5.99   5.99  6.03       300381.0          564.0
# 10  2020-03-05  7.44  7.51  7.33   7.48  7.41        31548.0          101.0
# ...

# %%
# Determining the data types of each column and evaluating whether they are appropriate for the nature of the variable.

print(index.columns)
print(type(index.columns))
print(index.dtypes)
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'WAP', 'No. of Shares',
#        'No. of Trades', 'Total Turnover', 'Deliverable Quantity',
#        '% Deli. Qty to Traded Qty', 'Spread H-L', 'Spread C-O'],
#       dtype='object')
# <class 'pandas.core.indexes.base.Index'>
# Date                          object
# Open                         float64
# High                         float64
# Low                          float64
# Close                        float64
# WAP                          float64
# No. of Shares                float64
# No. of Trades                float64
# Total Turnover               float64
# Deliverable Quantity         float64
# % Deli. Qty to Traded Qty    float64
# Spread H-L                   float64
# Spread C-O                   float64
# dtype: object

# %%
# Identify the number of unique values for each column.

unique_values_index = index.nunique()
print(unique_values_index)
# Out:
# Date                         2484
# Open                         1274
# High                         1325
# Low                          1295
# Close                        1393
# WAP                          2118
# No. of Shares                2462
# No. of Trades                1076
# Total Turnover               2484
# Deliverable Quantity         2427
# % Deli. Qty to Traded Qty    1940
# Spread H-L                    232
# Spread C-O                    273
# dtype: int64

# %%
#Reading the time series data of the share prices of Reliance Industries.
reliance = pd.read_csv("../data/raw/RELIANCE.NS.csv")
reliance.head(15)
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2010-03-18  531.957581  535.721863  527.054077  533.418701  483.463440
# 1   2010-03-19  534.335022  543.101929  530.050659  540.897827  490.242157
# 2   2010-03-22  526.013916  544.340210  526.013916  531.932800  482.116608
# 3   2010-03-23  533.914001  541.838928  533.418701  540.575867  489.950317
# 4   2010-03-25  542.854309  543.349609  533.641602  540.600647  489.972748
# 5   2010-03-26  543.349609  550.283875  542.433289  545.058411  494.013031
# 6   2010-03-29  546.668152  549.763794  540.377747  541.516968  490.803284
# 7   2010-03-30  542.854309  547.658752  536.415344  538.966125  488.491302
# 8   2010-03-31  541.318848  542.359009  530.620239  532.081421  482.251282
# 9   2010-04-01  533.938782  544.092529  533.443481  540.897827  490.242157
# 10  2010-04-05  543.101929  559.521301  543.101929  557.663879  505.437927
# ...

# %%
# Determining the data types of each column and evaluating whether they are appropriate for the nature of the variable.

print(reliance.columns)
print(type(reliance.columns))
print(reliance.dtypes)
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')
# <class 'pandas.core.indexes.base.Index'>
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume       float64
# dtype: object

# %%
# Identify the number of unique values for each column.

unique_values_reliance = reliance.nunique()
print(unique_values_reliance)
# Out:
# Date         2473
# Open         1959
# High         2078
# Low          2113
# Close        2265
# Adj Close    2387
# Volume       2466
# dtype: int64

# %%
#Reading the time series data of the share prices of Tata Motors.
tata = pd.read_csv("../data/raw/TATAMOTORS.BO.csv")
tata.head(15)
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2010-03-18  156.399994  157.190002  154.830002  156.029999  125.458351
# 1   2010-03-19  156.559998  157.339996  155.270004  156.740005  126.029259
# 2   2010-03-22  154.979996  156.500000  151.610001  152.000000  122.217964
# 3   2010-03-23  152.399994  154.190002  147.209991  147.809998  118.848930
# 4   2010-03-25  146.800003  147.600006  142.899994  145.050003  116.629730
# 5   2010-03-26  145.800003  151.449997  145.600006  149.929993  120.553558
# 6   2010-03-29  150.740005  152.000000  147.029999  147.929993  118.945435
# 7   2010-03-30  149.199997  151.949997  148.399994  151.259995  121.622963
# 8   2010-03-31  152.000000  153.339996  150.399994  151.139999  121.526474
# 9   2010-04-01  151.000000  156.000000  151.000000  155.179993  124.774902
# 10  2010-04-05  157.979996  157.979996  153.619995  156.169998  125.570930
# ...

# %%
# Determining the data types of each column and evaluating whether they are appropriate for the nature of the variable.

print(tata.columns)
print(type(tata.columns))
print(tata.dtypes)
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')
# <class 'pandas.core.indexes.base.Index'>
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume       float64
# dtype: object

# %%
# Identify the number of unique values for each column.

unique_values_tata = tata.nunique()
print(unique_values_tata)
# Out:
# Date         2473
# Open         1762
# High         2075
# Low          2069
# Close        2193
# Adj Close    2342
# Volume       2464
# dtype: int64

# %%
#Reading the time series data of the share prices of Piramal Enterprises.
piramal = pd.read_csv("../data/raw/PEL.NS.csv")
piramal.head(15)
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2010-03-18  412.443481  412.443481  404.679840  405.407684  290.369202
# 1   2010-03-19  408.464600  408.561646  397.886627  400.118683  286.581085
# 2   2010-03-22  396.916199  404.582794  394.004822  398.857086  285.677429
# 3   2010-03-23  406.572205  417.780975  400.846527  413.559479  296.207916
# 4   2010-03-25  416.325287  424.574158  409.677673  418.945526  300.065582
# 5   2010-03-26  425.059387  426.806213  408.658691  411.230408  294.539734
# 6   2010-03-29  411.958252  411.958252  401.914032  403.612335  289.083313
# 7   2010-03-30  405.650299  415.354828  403.224152  410.599609  294.087921
# 8   2010-03-31  415.257782  415.354828  407.688232  412.200867  295.234772
# 9   2010-04-01  414.821075  414.821075  406.620728  410.454041  293.983673
# 10  2010-04-05  413.899139  425.593140  411.181885  423.797791  303.540924
# ...

# %%
# Determining the data types of each column and evaluating whether they are appropriate for the nature of the variable.

print(piramal.columns)
print(type(piramal.columns))
print(piramal.dtypes)
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')
# <class 'pandas.core.indexes.base.Index'>
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume       float64
# dtype: object

# %%
# Identify the number of unique values for each column.

unique_values_piramal = piramal.nunique()
print(unique_values_piramal)
# Out:
# Date         2473
# Open         2041
# High         2061
# Low          2117
# Close        2329
# Adj Close    2395
# Volume       2458
# dtype: int64

# %%
#Reading the time series data of the share prices of State Bank of India.
sbi = pd.read_csv("../data/raw/SBIN.NS.csv")
sbi.head(15)
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2010-03-18  203.000000  205.050003  201.050003  202.964996  174.269547
# 1   2010-03-19  204.000000  206.585007  203.330002  205.845001  176.742386
# 2   2010-03-22  202.514999  205.380005  201.000000  204.095001  175.239792
# 3   2010-03-23  204.199997  205.664993  201.860001  204.854996  175.892349
# 4   2010-03-25  204.464996  206.160004  202.520004  204.955002  175.978195
# 5   2010-03-26  205.485001  207.800003  204.505005  207.285004  177.978775
# 6   2010-03-29  207.500000  210.500000  207.300003  209.505005  179.884933
# 7   2010-03-30  209.505005  212.195007  207.500000  208.255005  178.811630
# 8   2010-03-31  208.500000  209.889999  207.335007  207.820007  178.438171
# 9   2010-04-01  208.000000  210.800003  207.529999  210.259995  180.533157
# 10  2010-04-05  211.500000  214.220001  210.500000  213.824997  183.594131
# ...

# %%
# Determining the data types of each column and evaluating whether they are appropriate for the nature of the variable.

print(sbi.columns)
print(type(sbi.columns))
print(sbi.dtypes)
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')
# <class 'pandas.core.indexes.base.Index'>
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume       float64
# dtype: object

# %%
# Identify the number of unique values for each column.

unique_values_sbi = sbi.nunique()
print(unique_values_sbi)
# Out:
# Date         2473
# Open         1703
# High         1902
# Low          1950
# Close        2147
# Adj Close    2313
# Volume       2466
# dtype: int64

# %%
#Reading the time series data of the share prices of Hindustan Unilever.
hul = pd.read_csv("../data/raw/HINDUNILVR.NS.csv")
hul.head(15)
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2010-03-18  224.000000  226.949997  223.600006  224.850006  175.380508
# 1   2010-03-19  224.850006  229.899994  224.500000  228.949997  178.578461
# 2   2010-03-22  228.000000  229.500000  226.000000  228.250000  178.032425
# 3   2010-03-23  228.750000  230.300003  227.600006  228.500000  178.227478
# 4   2010-03-25  226.000000  234.000000  226.000000  232.000000  180.957458
# 5   2010-03-26  233.800003  239.399994  232.100006  238.500000  186.027390
# 6   2010-03-29  238.800003  240.399994  238.000000  239.699997  186.963333
# 7   2010-03-30  240.000000  242.300003  239.149994  241.850006  188.640335
# 8   2010-03-31  241.100006  242.000000  238.050003  239.550003  186.846329
# 9   2010-04-01  240.399994  240.449997  230.000000  230.399994  179.709442
# 10  2010-04-05  231.100006  232.350006  226.649994  229.100006  178.695450
# ...

# %%
# Determining the data types of each column and evaluating whether they are appropriate for the nature of the variable.

print(hul.columns)
print(type(hul.columns))
print(hul.dtypes)
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')
# <class 'pandas.core.indexes.base.Index'>
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume       float64
# dtype: object

# %%
# Identify the number of unique values for each column and determine which columns appear to be categorical.

unique_values_hul = hul.nunique()
print(unique_values_hul)
# Out:
# Date         2473
# Open         1995
# High         2177
# Low          2221
# Close        2319
# Adj Close    2388
# Volume       2465
# dtype: int64
