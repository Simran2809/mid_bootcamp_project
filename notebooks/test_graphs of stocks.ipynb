# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the historical data into a pandas DataFrame
nifty50 = pd.read_csv("../data/raw/^NSEI.csv")

#Auto sector
eicher = pd.read_csv("../data/raw/EICHERMOT.NS.csv")
tata = pd.read_csv("../data/raw/TATAMOTORS.NS.csv")
mahindra = pd.read_csv("../data/raw/M&M.NS.csv")
maruti = pd.read_csv("../data/raw/MARUTI.NS.csv")

# Pharma sector
piramal = pd.read_csv("../data/raw/PEL.NS.csv")
sun = pd.read_csv("../data/raw/SUNPHARMA.NS.csv")
reddy = pd.read_csv("../data/raw/RDY.csv")
apollo = pd.read_csv("../data/raw/APOLLOHOSP.NS.csv")

#Banking secotr
sbi = pd.read_csv("../data/raw/SBIN.NS.csv")
icici = pd.read_csv("../data/raw/ICICIBANK.NS.csv")
hdfc = pd.read_csv("../data/raw/HDB.csv")
bajaj = pd.read_csv("../data/raw/BAJFINANCE.NS.csv")

# %%
# Convert the 'Date' column to datetime format
eicher = pd.read_csv("../data/raw/EICHERMOT.NS.csv")

# Set the 'Date' column as the index
eicher.set_index('Date', inplace=True)

# Extract the 'Close' price column for plotting
close_prices_eicher= eicher['Close']
close_prices_eicher
# Out:
# Date
# 2013-04-01     255.184998
# 2013-04-02     270.250000
# 2013-04-03     269.700012
# 2013-04-04     265.774994
# 2013-04-05     266.429993
#                  ...
# 2023-03-23    2927.699951
# 2023-03-24    2909.600098
# 2023-03-27    2885.550049
# 2023-03-28    2852.399902
# 2023-03-29    2933.699951
# Name: Close, Length: 2469, dtype: float64

# %%
# Plotting the closing prices
plt.figure(figsize=(10, 6))
plt.plot(close_prices_eicher, color='grey')
plt.title('Eicher Motors Limited Stock Price')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.grid(True)
plt.show()

# %%
# Convert the 'Date' column to datetime format
tata['Date'] = pd.to_datetime(tata['Date'])

# Set the 'Date' column as the index
tata.set_index('Date', inplace=True)

# Extract the 'Close' price column for plotting
close_prices_tata= tata['Close']
close_prices_tata
# Out:
# Date
# 2013-04-01    262.682465
# 2013-04-02    264.364441
# 2013-04-03    254.470551
# 2013-04-04    254.965240
# 2013-04-05    252.491776
#                  ...
# 2023-03-23    419.149994
# 2023-03-24    416.500000
# 2023-03-27    412.049988
# 2023-03-28    401.600006
# 2023-03-29    409.200012
# Name: Close, Length: 2469, dtype: float64

# %%
# Plotting the closing prices
plt.figure(figsize=(10, 6))
plt.plot(close_prices, color='blue')
plt.title('Tata Motors Stock Price')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 # Plotting the closing prices
#       2 plt.figure(figsize=(10, 6))
# ----> 3 plt.plot(close_prices, color='blue')
#       4 plt.title('Tata Motors Stock Price')
#       5 plt.xlabel('Date')
#
# NameError: name 'close_prices' is not defined
